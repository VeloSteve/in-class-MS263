# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([-4, -2, 2, 4, -4])
y = np.array([0, 2, 2, 0, 0])
plt.figure()
plt.plot(x, y, lw=2)
plt.axis('square')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-4.4000000000000004,
#  4.4000000000000004,
#  -0.10000000000000001,
#  8.7000000000000011)

# %%
def rotateByDegrees(deg):
    mat = np.zeros([3,3])
    angle = deg*np.pi/180.0
    mat[0,0] = np.cos(angle)
    mat[0,1] = np.sin(angle)
    mat[1,0] = -np.sin(angle)
    mat[1,1] = np.cos(angle)
    mat[2,2] = 1
    return mat
    

# Shift by 4 to the right.
# note that np.eye(x) would fill the identity parts.
right4 = np.array([[1, 0, 4], [0, 1, 0], [0, 0, 1]])
clockwise = rotateByDegrees(90)
print(clockwise)
oldTrap = np.array([x, y, np.ones([5])])
newTrap = np.dot(right4, oldTrap)
newTrap = np.dot(clockwise, newTrap)
# Also can use np.matmul(A,B)
# or A@B
# order matters!

# See also hstack, vstack, stack (same as vstack)
plt.figure()
plt.plot(newTrap[0, :], newTrap[1, :], lw=2)
plt.axis('square')
# Out:
# [[ 0.5        0.8660254  0.       ]
#  [-0.8660254  0.5        0.       ]
#  [ 0.         0.         1.       ]]
# <img src="data:image/png;base64,..." width="640">
# (-0.23660254037844394,
#  7.3844210129246157,
#  -7.2746133917892841,
#  0.34641016151377535)

# %%
import time
plt.figure()
# Shear
ident = np.array([[1, 0, 0], [0, 1, 0], [0, 0, 1]])
for i in range(0, 10):
    shear = ident
    shear[0,1] = np.mod(i, 5)
    newTrap = np.dot(shear, oldTrap)
    plt.plot(newTrap[0, :], newTrap[1, :], lw=2)
    plt.axis('square')
    plt.show()
    time.sleep(1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import cbsyst
import pandas as pd
# you may need to change this, depending on where your data file is
filename = '../week03_wcoa_cruise/WCOA2013_hy1.csv' 
df = pd.read_csv(filename,header=31,na_values=-999,
                 parse_dates=[[8,9]])

# Create a new data frame, using only cast number 12
idx = (df['STNNBR'] == 12)
cast = df.loc[idx]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4a9bd0c36684> in <module>()
#       2 # you may need to change this, depending on where your data file is
#       3 filename = '../week03_wcoa_cruise/WCOA2013_hy1.csv'
# ----> 4 df = pd.read_csv(filename,header=31,na_values=-999,
#       5                  parse_dates=[[8,9]])
#       6
#
# NameError: name 'pd' is not defined
